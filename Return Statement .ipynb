# %% [markdown]
# RETURN STATEMENT - when we call a python fuction, sometimes we want information back from the function. e.g. a particular value or how the task went. The return keywork allows us to get information from the function.

# %%
def cube(num):
    return num*num*num
    
print(cube(4))
# Out:
# 64

# %%
def cube(num):
    return num*num*num
    
result = cube(4)
print(result)
# Out:
# 64
